# %%
i=1
while (i<11):
    print(3*i)
    i=i+1
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30

# %%
#argyument with no return value
def add(a,b):
    print(a+b)
add(10,3)
# Out:
# 13

# %%
# no arg noe return value
def greet():
    print("Hello")
greet()
greet()
# Out:
# Hello
# Hello

# %%
#arg and return value both
def sum(a,b):
    return a+b
addition = sum(10,2)
print(addition)
# Out:
# 12

# %%
add = lambda a, b: a + b
print(add(3, 4))
# Out:
# 7

# %%
sq = lambda a: a*a
print(sq(6))
# Out:
# 36

# %%
n=67
print(type(n))
print(2*n)
# Out:
# <class 'int'>
# 134

# %%
x="50000"
y=int(x)
print(type(y))
y+5000
# Out:
# <class 'int'>
# 55000

# %%
f=int(input("temp:"))
if f>=30:
    print("Hot")
elif f>=15:
    print("Normal")
else:
    print("Cold")
# Out:
# temp: 9
# Cold

# %%
count =0
for i in range(1,10):
    print(7*i)
    count=count+1
    
count
# Out:
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 9

# %%
n=67
rev=0
while n>0:
    digit=n%10
    rev=rev*10+digit
    n=n//10
rev
# Out:
# 76

# %%
def check_even_odd(n):
    if n % 2 == 0:
        print("Even number")
    else:
        print("Odd number")

num = int(input("Enter a number: "))
check_even_odd(num)
# Out:
# Enter a number:  9
# Odd number

# %%
marks=[10,20,30,40]
marks[1]
# Out:
# 20

# %%
marks[-1]
# Out:
# 40

# %%
marks.append(100)
marks
# Out:
# [10, 20, 30, 40, 100]

# %%
marks.insert(1,125)
marks
# Out:
# [10, 125, 20, 30, 40, 100]

# %%
marks.remove(125)
marks
# Out:
# [10, 20, 30, 40, 100]

# %%
marks.pop()
marks
# Out:
# [10, 20, 30, 40]

# %%
age=[18,19,25,23,36]
age.reverse()
age
# Out:
# [36, 23, 25, 19, 18]

# %%
age.sort()
age
# Out:
# [18, 19, 23, 25, 36]

# %%
print(max(age))
# Out:
# 36

# %%
summ = sum(age)
print(summ)
# Out:
# 121

# %%
len(marks)
# Out:
# 4

# %%
city = ["RKE", "HDR"," X", "Y"]
print(city[0])
print(city[1])
city.append("Z")
city
# Out:
# RKE
# HDR
# ['RKE', 'HDR', ' X', 'Y', 'Z']

# %%
city.reverse()
city.pop()
city
# Out:
# ['Z', 'Y', ' X', 'HDR']

# %%
city.sort()
city
# Out:
# [' X', 'HDR', 'Y', 'Z']

# %%
len(city)
# Out:
# 4

# %% [markdown]
# ### Tuple

# %%
days=('monday','tuesdy','wednesday','thursday')
print(days[-1])
# Out:
# thursday

# %%
days.count('monday')
# Out:
# 1

# %%
days.index('thursday')
# Out:
# 3

# %%
len(days)
# Out:
# 4

# %%
print('monday' in days)
# Out:
# True

# %% [markdown]
# ### Set

# %%
num={10,20,30,40,10}
for i in num:
    print(i)
# Out:
# 40
# 10
# 20
# 30

# %%
print(num)
# Out:
# {40, 10, 20, 30}

# %%
num.add(100)
num
# Out:
# {10, 20, 30, 40, 100}

# %%
num.update([120,130])
num
# Out:
# {20, 100, 120, 130}

# %%
num.discard(40)
num
# Out:
# {20, 100, 120, 130}

# %%
num.remove(30)
num
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 num.remove(30)
#       2 num
#
# KeyError: 30

# %%
num.pop()
# Out:
# 130

# %% [markdown]
# #### Dictionary

# %%
stud = {"Name":"Rahul","age":2,"City":"Delhi"}
stud
# Out:
# {'Name': 'Rahul', 'age': 2, 'City': 'Delhi'}

# %%
print(stud["Name"])
# Out:
# Rahul

# %%
stud.get("age")
# Out:
# 2

# %%
stud.keys()
# Out:
# dict_keys(['Name', 'age', 'City'])

# %%
stud.values()
# Out:
# dict_values(['Rahul', 2, 'Delhi'])

# %%
stud["Roll no."]=21 
stud
# Out:
# {'Name': 'Rahul', 'age': 2, 'City': 'Delhi', 'Roll no.': 21}

# %%
stud["age"]=5
stud.items()
# Out:
# dict_items([('Name', 'Rahul'), ('age', 5), ('City', 'Delhi'), ('Roll no.', 21)])

# %%
stud.update({"age":46,"course":"Django"})
stud
# Out:
# {'Name': 'Rahul',
#  'age': 46,
#  'City': 'Delhi',
#  'Roll no.': 21,
#  'course': 'Django'}

# %%
stud.pop("City")
# Out:
# 'Delhi'

# %%
stud.popitem()
# Out:
# ('course', 'Django')

# %%
d1={"a":1,"b":3,"c":4}
d2=d1.copy()
d2
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
d1.update(d2)  ### will merge 2 dicts

# %%
stud.clear()
stud
# Out:
# {}

# %%
contact={}
while True:
    print("\n-----Contact book----")
    print("1.add conatct")
    print("2.view contact")
    print("3.search contact")
    print("4.delete contact")
    print("5.Exit")
    choice =input("enter ur choice here:")

# for adding contact 
    if choice=="1":
        name=input("enter name:")
        phone=input("phn no.")
        contact[name]=phone
        print("contact added successfully")
#for view contact 
    elif choice =="2":
        if contact:
            print("\n saved contact:")
            for name,phone in contact.items():
                print(name,":",phone)
        else:
             print("no contact found")

    # for search contact 
    elif choice=="3":
        name = input("enter name to search")
        if name in contacts:
            print("phn no.:",contact[name])
        else:
            print("contact not found")
    # delete contact we can also use contact.pop(name) method 
    elif choice =="4":
        name =input("enter name u want to delete ")
        if name in contact:
            del contact[name]
            print("contact deleted")
        else:
            print("Contact not found")
    #exit
    elif choice == "5":
        print("thank u for using this book")
        break
    else:
        print("invalid choice please try again")
# Out:
# -----Contact book----
# 1.add conatct
# 2.view contact
# 3.search contact
# 4.delete contact
# 5.Exit
# enter ur choice here: 5
# thank u for using this book

# %% [markdown]
# # ques 2

# %%
student = {}

while True:
    print("\n------ Student Record System ---------")
    print("1. Add student")
    print("2. View students")
    print("3. Search student")
    print("4. Delete student")
    print("5. Exit")

    choice = input("Enter your choice: ")

    # Add student
    if choice == "1":
        roll = input("Enter roll no.: ")
        name = input("Enter name: ")
        course = input("Enter course: ")
        student[roll] = {"name": name, "course": course}
        print("Student added successfully")

    # View students
    elif choice == "2":
        if student:
            print("\nAll Students:")
            for roll, info in student.items():
                print("Roll:", roll)
                print("Name:", info["name"])
                print("Course:", info["course"])
                print("----------------------")
        else:
            print("No student record found")

    # Search student
    elif choice == "3":
        roll = input("Enter roll no: ")
        if roll in student:
            print("Name:", student[roll]["name"])
            print("Course:", student[roll]["course"])
        else:
            print("Student record not found")

    # Delete student
    elif choice == "4":
        roll = input("Enter roll no to delete: ")
        if roll in student:
            del student[roll]
            print("Student record deleted successfully")
        else:
            print("Student record not found")

    # Exit
    elif choice == "5":
        print("Thank you for using Student Record System")
        break

    else:
        print("Invalid choice, please try again")
# Out:
# ------ Student Record System ---------
# 1. Add student
# 2. View students
# 3. Search student
# 4. Delete student
# 5. Exit
