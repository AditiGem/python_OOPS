# %% [raw]
# #file = open("data.txt","mode->r,w,a")
# file=open("students.txt","w")
# file.write("Name: Rahul\n")
# file.write("course: python\n")
# file.close()

# %%
file=open("students.txt","r")
data =file.read()
print(data)
file.close()
# Out:
# Name: Rahul
# course: python

# %%
# other method to read file 
with open("students.txt","r") as file:
    data = file.read()
    print(data)
# Out:
# Name: Rahul
# course: python

# %%
file =open("students.txt","a")
file.write("marks: 98")
file.close()

# %%
file=open("students.txt","r") 
data=file.readline()
print(data)
# Out:
# Name: Rahul

# %%
file=open("students.txt","r") 
data2=file.readlines()
print(data2)
# Out:
# ['Name: Rahul\n', 'course: python\n', 'marks: 98']

# %%
file = open("data.txt", "w")
file.close()

# %%
file = open("data.txt", "w")
file.write("name: Aditi\n")
file.write("City: Roorkee\n")
file .close()

# %%
file=open("data.txt","a")
file.write("Age:20\n")
file.close()

# %%
#read lines in the file 
file=open("data.txt","r")
data=file.readlines()
print(len(data))
# Out:
# 4

# %%
file=open("data.txt","r")
data=file.read()
print("character in the file",len(data))
file.close()
# Out:
# character in the file 58

# %%
file=open("data.txt","r")
data=file.read()
print(data.upper())
# Out:
# NAME: ADITI
# CITY: ROORKEE
# AGE:20AGE:20AGE:20AGE:20
# AGE:20

# %%
file=open("data.txt","r")
data=file.read()
words=data.split()
print(words)
file.close()
# Out:
# ['name:', 'Aditi', 'City:', 'Roorkee', 'Age:20Age:20Age:20Age:20', 'Age:20']

# %%
file=open("data.txt","r")
data=file.read()
# change to loower case so that we can count easily
count=data.lower().count("aditi")
print("word count",count)
file.close()
# Out:
# word count 1

# %%
file = open("data.txt", "r")
data = file.read()
file.close()
print(data[::-1])
# Out:
# 02:egA
# 02:egA02:egA02:egA02:egA
# eekrooR :ytiC
# itidA :eman

# %%
file = open("data.txt", "r")
data = file.read()
print(len(data))
print(data.replace("Aditi","siddhi"))
file.close()
# Out:
# 58
# name: siddhi
# City: Roorkee
# Age:20Age:20Age:20Age:20
# Age:20

# %%
file=open("movie.txt","w")
file.write("Hello Brother\n")
file.write("IT\n")
file.write("goodbye\n")
file.close()
file=open("movie.txt","r")
data=file.read()
print(data.replace(" ",""))
print(data[:10])
file.close()
# Out:
# HelloBrother
# IT
# goodbye
#
# Hello Brot

# %%
file=open("movie.txt","r")
data=file.read()
words=data.split()
for w in words:
    print(w[::-1])
file.close()
# Out:
# olleH
# rehtorB
# TI
# eybdoog
